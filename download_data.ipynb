# %%
# !pip install kagglehub

# %%
global kagglehub, shutil, os
import kagglehub
import shutil
import os
import zipfile

# %%
# -------------------------------
# Constants
# -------------------------------
COMPOSERS = ['Bach', 'Beethoven', 'Chopin', 'Mozart']
DATASET_ID = "blanderbuss/midi-classic-music"
MIDI_DATA_DIR = '/content/midi_data'
DESTINATION_DIR = "/tmp"
SOURCE_DATA_DIR = DESTINATION_DIR
SUPPORTED_EXT = ('.mid', '.midi')

# %%
# ----------------------------------
# Delete a folder and all its contents
# ----------------------------------
def delete_folder_recursive(folder_path):

    if os.path.exists(folder_path):
        try:
            shutil.rmtree(folder_path)
            print(f" Deleted folder and its contents: {folder_path}")
        except Exception as e:
            print(f"[ERROR] Failed to delete {folder_path}: {e}")
    else:
        print(f"[INFO] Folder does not exist: {folder_path}")

delete_folder_recursive("/content/midi_data")
# Out:
#  Deleted folder and its contents: /content/midi_data

# %%
# -------------------------------
# Download Dataset via KaggleHub
# -------------------------------
def download_dataset(dataset_id):
    print(f"Downloading dataset: {dataset_id}")
    dataset_path = kagglehub.dataset_download(dataset_id)
    print(f"Dataset downloaded to temporary path: {dataset_path}")
    return dataset_path

# -------------------------------
# Copy Dataset to Destination
# -------------------------------
def copy_dataset(source_path, destination_path):
    if not os.path.exists(destination_path):
        os.makedirs(destination_path)
        print(f"Created destination folder: {destination_path}")

    try:
        shutil.copytree(source_path, destination_path, dirs_exist_ok=True)
        print(f"Dataset copied from '{source_path}' to '{destination_path}'")
    except Exception as e:
        print(f"[ERROR] Could not copy dataset: {e}")

# ----------------------------------
# Create base output folder and composer folders
# ----------------------------------
def create_composer_folders(base_dir, composers):
    os.makedirs(base_dir, exist_ok=True)
    for composer in composers:
        composer_dir = os.path.join(base_dir, composer)
        os.makedirs(composer_dir, exist_ok=True)

# ----------------------------------
# Recursively extract all .zip files in a directory
# ----------------------------------
def extract_all_nested_zips(base_path):
    for root, dirs, files in os.walk(base_path):
        for file in files:
            if file.lower().endswith('.zip'):
                zip_path = os.path.join(root, file)
                extract_path = os.path.splitext(zip_path)[0]
                try:
                    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
                        zip_ref.extractall(extract_path)
                        print(f"Extracted: {zip_path} -> {extract_path}")
                except zipfile.BadZipFile:
                    print(f"[WARNING] Skipped invalid ZIP: {zip_path}")
                    continue
                except Exception as e:
                    print(f"[ERROR] Failed to extract {zip_path}: {e}")
                    continue
                # Recursively extract deeper levels
                extract_all_nested_zips(extract_path)

# ----------------------------------
# Copy .midi files to composer folders
# ----------------------------------
def copy_midi_files_to_composer_folders(source_dir, target_dir, composers):
    for root, dirs, files in os.walk(source_dir):
        for file in files:
            if file.lower().endswith('.mid') or file.lower().endswith('.midi'):
                full_path = os.path.join(root, file)
                for composer in composers:
                    if composer.lower() in full_path.lower():
                        destination = os.path.join(target_dir, composer, file)
                        try:
                            shutil.copy2(full_path, destination)
                            print(f"Copied: {full_path} -> {destination}")
                        except Exception as e:
                            print(f"[ERROR] Failed to copy {full_path}: {e}")
                        break

# ----------------------------------
# Orchestrator function
# ----------------------------------
def organize_midi_data():
    # Step 1: Create output structure
    create_composer_folders(MIDI_DATA_DIR, COMPOSERS)

    # Step 2: Extract all ZIPs (even nested)
    extract_all_nested_zips(SOURCE_DATA_DIR)

    # Step 3: Copy relevant .midi files to target composer folders
    copy_midi_files_to_composer_folders(SOURCE_DATA_DIR, MIDI_DATA_DIR, COMPOSERS)

# ----------------------------------
# Print summary of .mid/.midi files per composer
# ----------------------------------
def print_midi_file_summary(composer_dir, composers):
    summary = {}

    for composer in composers:
        folder_path = os.path.join(composer_dir, composer)
        count = 0

        # Count .mid and .midi files only
        for file in os.listdir(folder_path):
            ext = os.path.splitext(file)[1].lower()
            if ext in ['.mid', '.midi']:
                count += 1

        summary[composer] = count

    print("\n MIDI File Summary per Composer:")
    print("----------------------------------")
    for composer, count in summary.items():
        print(f"{composer}: {count} files")



# -------------------------------
# Full Setup Pipeline
# -------------------------------
def setup_dataset():
    source = download_dataset(DATASET_ID)
    copy_dataset(source, DESTINATION_DIR)
    organize_midi_data()


setup_dataset()
print_midi_file_summary(MIDI_DATA_DIR, COMPOSERS)
# Out:
# Downloading dataset: blanderbuss/midi-classic-music
# Dataset downloaded to temporary path: /kaggle/input/midi-classic-music
# Dataset copied from '/kaggle/input/midi-classic-music' to '/tmp'
# Extracted: /tmp/midiclassics.zip -> /tmp/midiclassics
# Extracted: /tmp/midiclassics/Frescobaldi/Messa della Domenica (Orbis factor) from the Fiori Musicali.zip -> /tmp/midiclassics/Frescobaldi/Messa della Domenica (Orbis factor) from the Fiori Musicali
# Extracted: /tmp/midiclassics/Ravel/La Valse.zip -> /tmp/midiclassics/Ravel/La Valse
# Extracted: /tmp/midiclassics/Copland/Concerto for Clarinet.zip -> /tmp/midiclassics/Copland/Concerto for Clarinet
# Extracted: /tmp/midiclassics/Copland/Appalacian Spring.zip -> /tmp/midiclassics/Copland/Appalacian Spring
# Extracted: /tmp/midiclassics/Griffes/Piano Sonata.zip -> /tmp/midiclassics/Griffes/Piano Sonata
# Extracted: /tmp/midiclassics/Strauss, J/The blue danube Op.314.zip -> /tmp/midiclassics/Strauss, J/The blue danube Op.314
# Extracted: /tmp/midiclassics/Ginastera/Danza Final from his ballet  Estancia.zip -> /tmp/midiclassics/Ginastera/Danza Final from his ballet  Estancia
# Extracted: /tmp/midiclassics/Chabrier/Souvenirs de Munich.zip -> /tmp/midiclassics/Chabrier/Souvenirs de Munich
# Extracted: /tmp/midiclassics/Chabrier/Suite Pastorale 4 Scherzo-valse.zip -> /tmp/midiclassics/Chabrier/Suite Pastorale 4 Scherzo-valse
# Extracted: /tmp/midiclassics/Chabrier/Suite pastorale 2 Danse villageoise.zip -> /tmp/midiclassics/Chabrier/Suite pastorale 2 Danse villageoise
# Extracted: /tmp/midiclassics/Chabrier/Joyeuse marche.zip -> /tmp/midiclassics/Chabrier/Joyeuse marche
# Extracted: /tmp/midiclassics/Chabrier/Espan~a, rhapsody for orchestra (1883).zip -> /tmp/midiclassics/Chabrier/Espan~a, rhapsody for orchestra (1883)
# Extracted: /tmp/midiclassics/Rachmaninov/Paganini Variations No.9.zip -> /tmp/midiclassics/Rachmaninov/Paganini Variations No.9
# Extracted: /tmp/midiclassics/Rachmaninov/Piano Concerto, 3rd mov.zip -> /tmp/midiclassics/Rachmaninov/Piano Concerto, 3rd mov
# Extracted: /tmp/midiclassics/Dvorak/Suite in A Major for Piano Op.98 (American Suite.zip -> /tmp/midiclassics/Dvorak/Suite in A Major for Piano Op.98 (American Suite
# Extracted: /tmp/midiclassics/Dvorak/Slavonic Dance No. 8 Op. 46.zip -> /tmp/midiclassics/Dvorak/Slavonic Dance No. 8 Op. 46
# Extracted: /tmp/midiclassics/Scarlatti/v5.zip -> /tmp/midiclassics/Scarlatti/v5
# Extracted: /tmp/midiclassics/Mussorgski/Sonata in C major.zip -> /tmp/midiclassics/Mussorgski/Sonata in C major
# Extracted: /tmp/midiclassics/Busoni/Piano Concerto, Mov.3. A wonderful piece.zip -> /tmp/midiclassics/Busoni/Piano Concerto, Mov.3. A wonderful piece
# Extracted: /tmp/midiclassics/Busoni/Chacona in D, with variations.zip -> /tmp/midiclassics/Busoni/Chacona in D, with variations
# Extracted: /tmp/midiclassics/Busoni/Piano Concerto, Mov.4. Another wonderful piece.zip -> /tmp/midiclassics/Busoni/Piano Concerto, Mov.4. Another wonderful piece
# Extracted: /tmp/midiclassics/Busoni/Piano Concerto, Mov.1. A beautiful piece.zip -> /tmp/midiclassics/Busoni/Piano Concerto, Mov.1. A beautiful piece
# Extracted: /tmp/midiclassics/Busoni/Piano Concerto, Mov.5.zip -> /tmp/midiclassics/Busoni/Piano Concerto, Mov.5
# Extracted: /tmp/midiclassics/Schubert/Piano Sonata in B flat No.4, D960.zip -> /tmp/midiclassics/Schubert/Piano Sonata in B flat No.4, D960
# Extracted: /tmp/midiclassics/Beethoven/Piano Sonata No.23.zip -> /tmp/midiclassics/Beethoven/Piano Sonata No.23
# Extracted: /tmp/midiclassics/Beethoven/Piano Sonata No.18.zip -> /tmp/midiclassics/Beethoven/Piano Sonata No.18
# Extracted: /tmp/midiclassics/Beethoven/Sonata No.1 in D.zip -> /tmp/midiclassics/Beethoven/Sonata No.1 in D
# Extracted: /tmp/midiclassics/Beethoven/Complete Sonata in A flat major Op.110.zip -> /tmp/midiclassics/Beethoven/Complete Sonata in A flat major Op.110
# Extracted: /tmp/midiclassics/Beethoven/Complete Tempest Sonata.zip -> /tmp/midiclassics/Beethoven/Complete Tempest Sonata
# Extracted: /tmp/midiclassics/Beethoven/Piano and Cello Sonata No.2 Op 5.zip -> /tmp/midiclassics/Beethoven/Piano and Cello Sonata No.2 Op 5
# Extracted: /tmp/midiclassics/Frescobaldi/Messa della Domenica (Orbis factor) from the Fiori Musicali.zip -> /tmp/midiclassics/Frescobaldi/Messa della Domenica (Orbis factor) from the Fiori Musicali
# Extracted: /tmp/midiclassics/Ravel/La Valse.zip -> /tmp/midiclassics/Ravel/La Valse
# Extracted: /tmp/midiclassics/Copland/Concerto for Clarinet.zip -> /tmp/midiclassics/Copland/Concerto for Clarinet
# Extracted: /tmp/midiclassics/Copland/Appalacian Spring.zip -> /tmp/midiclassics/Copland/Appalacian Spring
# Extracted: /tmp/midiclassics/Griffes/Piano Sonata.zip -> /tmp/midiclassics/Griffes/Piano Sonata
# Extracted: /tmp/midiclassics/Strauss, J/The blue danube Op.314.zip -> /tmp/midiclassics/Strauss, J/The blue danube Op.314
# Extracted: /tmp/midiclassics/Ginastera/Danza Final from his ballet  Estancia.zip -> /tmp/midiclassics/Ginastera/Danza Final from his ballet  Estancia
# Extracted: /tmp/midiclassics/Chabrier/Souvenirs de Munich.zip -> /tmp/midiclassics/Chabrier/Souvenirs de Munich
# Extracted: /tmp/midiclassics/Chabrier/Suite Pastorale 4 Scherzo-valse.zip -> /tmp/midiclassics/Chabrier/Suite Pastorale 4 Scherzo-valse
# Extracted: /tmp/midiclassics/Chabrier/Suite pastorale 2 Danse villageoise.zip -> /tmp/midiclassics/Chabrier/Suite pastorale 2 Danse villageoise
# Extracted: /tmp/midiclassics/Chabrier/Joyeuse marche.zip -> /tmp/midiclassics/Chabrier/Joyeuse marche
# Extracted: /tmp/midiclassics/Chabrier/Espan~a, rhapsody for orchestra (1883).zip -> /tmp/midiclassics/Chabrier/Espan~a, rhapsody for orchestra (1883)
# Extracted: /tmp/midiclassics/Rachmaninov/Paganini Variations No.9.zip -> /tmp/midiclassics/Rachmaninov/Paganini Variations No.9
# Extracted: /tmp/midiclassics/Rachmaninov/Piano Concerto, 3rd mov.zip -> /tmp/midiclassics/Rachmaninov/Piano Concerto, 3rd mov
# Extracted: /tmp/midiclassics/Dvorak/Suite in A Major for Piano Op.98 (American Suite.zip -> /tmp/midiclassics/Dvorak/Suite in A Major for Piano Op.98 (American Suite
# Extracted: /tmp/midiclassics/Dvorak/Slavonic Dance No. 8 Op. 46.zip -> /tmp/midiclassics/Dvorak/Slavonic Dance No. 8 Op. 46
# Extracted: /tmp/midiclassics/Scarlatti/v5.zip -> /tmp/midiclassics/Scarlatti/v5
# Extracted: /tmp/midiclassics/Mussorgski/Sonata in C major.zip -> /tmp/midiclassics/Mussorgski/Sonata in C major
# Extracted: /tmp/midiclassics/Busoni/Piano Concerto, Mov.3. A wonderful piece.zip -> /tmp/midiclassics/Busoni/Piano Concerto, Mov.3. A wonderful piece
# Extracted: /tmp/midiclassics/Busoni/Chacona in D, with variations.zip -> /tmp/midiclassics/Busoni/Chacona in D, with variations
# Extracted: /tmp/midiclassics/Busoni/Piano Concerto, Mov.4. Another wonderful piece.zip -> /tmp/midiclassics/Busoni/Piano Concerto, Mov.4. Another wonderful piece
# Extracted: /tmp/midiclassics/Busoni/Piano Concerto, Mov.1. A beautiful piece.zip -> /tmp/midiclassics/Busoni/Piano Concerto, Mov.1. A beautiful piece
# Extracted: /tmp/midiclassics/Busoni/Piano Concerto, Mov.5.zip -> /tmp/midiclassics/Busoni/Piano Concerto, Mov.5
# Extracted: /tmp/midiclassics/Schubert/Piano Sonata in B flat No.4, D960.zip -> /tmp/midiclassics/Schubert/Piano Sonata in B flat No.4, D960
# Extracted: /tmp/midiclassics/Beethoven/Piano Sonata No.23.zip -> /tmp/midiclassics/Beethoven/Piano Sonata No.23
# Extracted: /tmp/midiclassics/Beethoven/Piano Sonata No.18.zip -> /tmp/midiclassics/Beethoven/Piano Sonata No.18
# Extracted: /tmp/midiclassics/Beethoven/Sonata No.1 in D.zip -> /tmp/midiclassics/Beethoven/Sonata No.1 in D
# Extracted: /tmp/midiclassics/Beethoven/Complete Sonata in A flat major Op.110.zip -> /tmp/midiclassics/Beethoven/Complete Sonata in A flat major Op.110
# Extracted: /tmp/midiclassics/Beethoven/Complete Tempest Sonata.zip -> /tmp/midiclassics/Beethoven/Complete Tempest Sonata
# Extracted: /tmp/midiclassics/Beethoven/Piano and Cello Sonata No.2 Op 5.zip -> /tmp/midiclassics/Beethoven/Piano and Cello Sonata No.2 Op 5
# Copied: /tmp/midiclassics/C.P.E.Bach Solfeggieto.mid -> /content/midi_data/Bach/C.P.E.Bach Solfeggieto.mid
# Copied: /tmp/midiclassics/Liszt Bach Prelude Transcription.mid -> /content/midi_data/Bach/Liszt Bach Prelude Transcription.mid
# Copied: /tmp/midiclassics/Mozart/K626 Requiem 06 confutatis.mid -> /content/midi_data/Mozart/K626 Requiem 06 confutatis.mid
# Copied: /tmp/midiclassics/Mozart/K339 Vesperae solemnes de confessore (Vespers) 1mov Dixit Dominus.mid -> /content/midi_data/Mozart/K339 Vesperae solemnes de confessore (Vespers) 1mov Dixit Dominus.mid
# Copied: /tmp/midiclassics/Mozart/K573 9 Variations for Piano Uber Duport.mid -> /content/midi_data/Mozart/K573 9 Variations for Piano Uber Duport.mid
# Copied: /tmp/midiclassics/Mozart/Viennese Sonatinas K439b n2 2mov.mid -> /content/midi_data/Mozart/Viennese Sonatinas K439b n2 2mov.mid
# Copied: /tmp/midiclassics/Mozart/K622 Clarinet Concerto 1mov.mid -> /content/midi_data/Mozart/K622 Clarinet Concerto 1mov.mid
# Copied: /tmp/midiclassics/Mozart/K03 Allegro in Bb.mid -> /content/midi_data/Mozart/K03 Allegro in Bb.mid
# Copied: /tmp/midiclassics/Mozart/K191 Bassoon Concerto 3mov.mid -> /content/midi_data/Mozart/K191 Bassoon Concerto 3mov.mid
# Copied: /tmp/midiclassics/Mozart/K335 Laudate Dominus.mid -> /content/midi_data/Mozart/K335 Laudate Dominus.mid
# Copied: /tmp/midiclassics/Mozart/K04 Minuet in F.mid -> /content/midi_data/Mozart/K04 Minuet in F.mid
# Copied: /tmp/midiclassics/Mozart/K617 Adagio.mid -> /content/midi_data/Mozart/K617 Adagio.mid
# Copied: /tmp/midiclassics/Mozart/K317 Coronation Mass 2mov.mid -> /content/midi_data/Mozart/K317 Coronation Mass 2mov.mid
# Copied: /tmp/midiclassics/Mozart/K626 Requiem 04 Dies Irae.mid -> /content/midi_data/Mozart/K626 Requiem 04 Dies Irae.mid
# Copied: /tmp/midiclassics/Mozart/Viennese Sonatinas K439b n6 1mov.mid -> /content/midi_data/Mozart/Viennese Sonatinas K439b n6 1mov.mid
# Copied: /tmp/midiclassics/Mozart/K393 Solfeggi n2.mid -> /content/midi_data/Mozart/K393 Solfeggi n2.mid
# Copied: /tmp/midiclassics/Mozart/K525 Serenade 4mov ''Eine Kleine Natchmusik''.mid -> /content/midi_data/Mozart/K525 Serenade 4mov ''Eine Kleine Natchmusik''.mid
# Copied: /tmp/midiclassics/Mozart/K393 Solfeggi n5.mid -> /content/midi_data/Mozart/K393 Solfeggi n5.mid
# Copied: /tmp/midiclassics/Mozart/K299 Flute Harp Concerto 2mov.mid -> /content/midi_data/Mozart/K299 Flute Harp Concerto 2mov.mid
# Copied: /tmp/midiclassics/Mozart/K594 Adagio & Allegro for Mechanical Organ.mid -> /content/midi_data/Mozart/K594 Adagio & Allegro for Mechanical Organ.mid
# Copied: /tmp/midiclassics/Mozart/K393 Solfeggi n3.mid -> /content/midi_data/Mozart/K393 Solfeggi n3.mid
# Copied: /tmp/midiclassics/Mozart/Viennese Sonatinas K439b n6 2mov.mid -> /content/midi_data/Mozart/Viennese Sonatinas K439b n6 2mov.mid
# Copied: /tmp/midiclassics/Mozart/K361 Serenade n10 3mov.mid -> /content/midi_data/Mozart/K361 Serenade n10 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Sonatina n3 1mov.mid -> /content/midi_data/Mozart/Sonatina n3 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Another piece for Piano,K.176.mid -> /content/midi_data/Mozart/Another piece for Piano,K.176.mid
# Copied: /tmp/midiclassics/Mozart/K317 Coronation Mass 5mov.mid -> /content/midi_data/Mozart/K317 Coronation Mass 5mov.mid
# Copied: /tmp/midiclassics/Mozart/K626 Requiem 08 offertorio domine jesu.mid -> /content/midi_data/Mozart/K626 Requiem 08 offertorio domine jesu.mid
# Copied: /tmp/midiclassics/Mozart/K626 Requiem 03 tuba mirum.mid -> /content/midi_data/Mozart/K626 Requiem 03 tuba mirum.mid
# Copied: /tmp/midiclassics/Mozart/K393 Solfeggi n4.mid -> /content/midi_data/Mozart/K393 Solfeggi n4.mid
# Copied: /tmp/midiclassics/Mozart/K02 Minuet in F.mid -> /content/midi_data/Mozart/K02 Minuet in F.mid
# Copied: /tmp/midiclassics/Mozart/K317 Coronation Mass 4mov.mid -> /content/midi_data/Mozart/K317 Coronation Mass 4mov.mid
# Copied: /tmp/midiclassics/Mozart/K622 Clarinet Concerto 3mov.mid -> /content/midi_data/Mozart/K622 Clarinet Concerto 3mov.mid
# Copied: /tmp/midiclassics/Mozart/K299 Flute Harp Concerto 1mov.mid -> /content/midi_data/Mozart/K299 Flute Harp Concerto 1mov.mid
# Copied: /tmp/midiclassics/Mozart/K495 Horn Concerto n4 2mov.mid -> /content/midi_data/Mozart/K495 Horn Concerto n4 2mov.mid
# Copied: /tmp/midiclassics/Mozart/K136 Divertimento 2mov.mid -> /content/midi_data/Mozart/K136 Divertimento 2mov.mid
# Copied: /tmp/midiclassics/Mozart/Rondo in C.mid -> /content/midi_data/Mozart/Rondo in C.mid
# Copied: /tmp/midiclassics/Mozart/K626 Requiem 01 Introitus & Kyrie.mid -> /content/midi_data/Mozart/K626 Requiem 01 Introitus & Kyrie.mid
# Copied: /tmp/midiclassics/Mozart/K317 Coronation Mass 3mov.mid -> /content/midi_data/Mozart/K317 Coronation Mass 3mov.mid
# Copied: /tmp/midiclassics/Mozart/K501 Andante with 5 Variations for Piano Duet.mid -> /content/midi_data/Mozart/K501 Andante with 5 Variations for Piano Duet.mid
# Copied: /tmp/midiclassics/Mozart/K05 Minuet for Harpsichord.mid -> /content/midi_data/Mozart/K05 Minuet for Harpsichord.mid
# Copied: /tmp/midiclassics/Mozart/Sonatina n21 3mov.mid -> /content/midi_data/Mozart/Sonatina n21 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Adagio in B flat.mid -> /content/midi_data/Mozart/Adagio in B flat.mid
# Copied: /tmp/midiclassics/Mozart/K401 Fuga in G minor .mid -> /content/midi_data/Mozart/K401 Fuga in G minor .mid
# Copied: /tmp/midiclassics/Mozart/Contradance n3.mid -> /content/midi_data/Mozart/Contradance n3.mid
# Copied: /tmp/midiclassics/Mozart/Rondo.mid -> /content/midi_data/Mozart/Rondo.mid
# Copied: /tmp/midiclassics/Mozart/K546 Adagio & Fugue for Strings.mid -> /content/midi_data/Mozart/K546 Adagio & Fugue for Strings.mid
# Copied: /tmp/midiclassics/Mozart/Contradance n2.mid -> /content/midi_data/Mozart/Contradance n2.mid
# Copied: /tmp/midiclassics/Mozart/Contradance n1.mid -> /content/midi_data/Mozart/Contradance n1.mid
# Copied: /tmp/midiclassics/Mozart/K495 Horn Concerto n4 3mov.mid -> /content/midi_data/Mozart/K495 Horn Concerto n4 3mov.mid
# Copied: /tmp/midiclassics/Mozart/K618 Ave Verum Corpus.mid -> /content/midi_data/Mozart/K618 Ave Verum Corpus.mid
# Copied: /tmp/midiclassics/Mozart/K398 Piano Variations ''Salve Tu Domine''.mid -> /content/midi_data/Mozart/K398 Piano Variations ''Salve Tu Domine''.mid
# Copied: /tmp/midiclassics/Mozart/K525 Serenade 2mov ''Eine Kleine Natchmusik''.mid -> /content/midi_data/Mozart/K525 Serenade 2mov ''Eine Kleine Natchmusik''.mid
# Copied: /tmp/midiclassics/Mozart/K525 Serenade 3mov ''Eine Kleine Natchmusik''.mid -> /content/midi_data/Mozart/K525 Serenade 3mov ''Eine Kleine Natchmusik''.mid
# Copied: /tmp/midiclassics/Mozart/K626 Requiem kyrie.mid -> /content/midi_data/Mozart/K626 Requiem kyrie.mid
# Copied: /tmp/midiclassics/Mozart/K626 Requiem 10 Sanctus.mid -> /content/midi_data/Mozart/K626 Requiem 10 Sanctus.mid
# Copied: /tmp/midiclassics/Mozart/K299 Flute Harp Concerto 3mov.mid -> /content/midi_data/Mozart/K299 Flute Harp Concerto 3mov.mid
# Copied: /tmp/midiclassics/Mozart/K626 Requiem 02 rextremendae.mid -> /content/midi_data/Mozart/K626 Requiem 02 rextremendae.mid
# Copied: /tmp/midiclassics/Mozart/K393 Solfeggi n1.mid -> /content/midi_data/Mozart/K393 Solfeggi n1.mid
# Copied: /tmp/midiclassics/Mozart/K136 Divertimento 3mov.mid -> /content/midi_data/Mozart/K136 Divertimento 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Viennese Sonatinas K439b n2 4mov.mid -> /content/midi_data/Mozart/Viennese Sonatinas K439b n2 4mov.mid
# Copied: /tmp/midiclassics/Mozart/K626 Requiem 11 Benedictus.mid -> /content/midi_data/Mozart/K626 Requiem 11 Benedictus.mid
# Copied: /tmp/midiclassics/Mozart/K317 Coronation Mass 6mov.mid -> /content/midi_data/Mozart/K317 Coronation Mass 6mov.mid
# Copied: /tmp/midiclassics/Mozart/K314 Flute Concerto n2 1mov.mid -> /content/midi_data/Mozart/K314 Flute Concerto n2 1mov.mid
# Copied: /tmp/midiclassics/Mozart/K354 Piano Variations ''Je Suis Lindor''.mid -> /content/midi_data/Mozart/K354 Piano Variations ''Je Suis Lindor''.mid
# Copied: /tmp/midiclassics/Mozart/Fantasia in C K.475.mid -> /content/midi_data/Mozart/Fantasia in C K.475.mid
# Copied: /tmp/midiclassics/Mozart/K527 Overture ''Don Giovanni''.mid -> /content/midi_data/Mozart/K527 Overture ''Don Giovanni''.mid
# Copied: /tmp/midiclassics/Mozart/K317 Coronation Mass 1mov.mid -> /content/midi_data/Mozart/K317 Coronation Mass 1mov.mid
# Copied: /tmp/midiclassics/Mozart/K191 Bassoon Concerto 2mov.mid -> /content/midi_data/Mozart/K191 Bassoon Concerto 2mov.mid
# Copied: /tmp/midiclassics/Mozart/K608 Fantasia for Mechanical Organ.mid -> /content/midi_data/Mozart/K608 Fantasia for Mechanical Organ.mid
# Copied: /tmp/midiclassics/Mozart/Vesperae solemnes de confessore ''Vespers'' K339 1 Dixit Dominus.mid -> /content/midi_data/Mozart/Vesperae solemnes de confessore ''Vespers'' K339 1 Dixit Dominus.mid
# Copied: /tmp/midiclassics/Mozart/K117 Offertorio Jubilate Deo.mid -> /content/midi_data/Mozart/K117 Offertorio Jubilate Deo.mid
# Copied: /tmp/midiclassics/Mozart/K136 Divertimento 1mov.mid -> /content/midi_data/Mozart/K136 Divertimento 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Sonatina n3 2mov.mid -> /content/midi_data/Mozart/Sonatina n3 2mov.mid
# Copied: /tmp/midiclassics/Mozart/K626 Requiem 12 agnus dei.mid -> /content/midi_data/Mozart/K626 Requiem 12 agnus dei.mid
# Copied: /tmp/midiclassics/Mozart/Sonatina n22 4mov.mid -> /content/midi_data/Mozart/Sonatina n22 4mov.mid
# Copied: /tmp/midiclassics/Mozart/K427 Great Mass 1mov.mid -> /content/midi_data/Mozart/K427 Great Mass 1mov.mid
# Copied: /tmp/midiclassics/Mozart/K626 Requiem 05 Recordare.mid -> /content/midi_data/Mozart/K626 Requiem 05 Recordare.mid
# Copied: /tmp/midiclassics/Mozart/K525 Serenade 1mov ''Eine Kleine Natchmusik''.mid -> /content/midi_data/Mozart/K525 Serenade 1mov ''Eine Kleine Natchmusik''.mid
# Copied: /tmp/midiclassics/Mozart/K314 Flute Concerto n2 2mov.mid -> /content/midi_data/Mozart/K314 Flute Concerto n2 2mov.mid
# Copied: /tmp/midiclassics/Mozart/K626 Requiem 09 hostias.mid -> /content/midi_data/Mozart/K626 Requiem 09 hostias.mid
# Copied: /tmp/midiclassics/Mozart/Sonatina n3 3mov.mid -> /content/midi_data/Mozart/Sonatina n3 3mov.mid
# Copied: /tmp/midiclassics/Mozart/K622 Clarinet Concerto 2mov.mid -> /content/midi_data/Mozart/K622 Clarinet Concerto 2mov.mid
# Copied: /tmp/midiclassics/Mozart/K620 Overture The Magic Flute.mid -> /content/midi_data/Mozart/K620 Overture The Magic Flute.mid
# Copied: /tmp/midiclassics/Mozart/K191 Bassoon Concerto 1mov.mid -> /content/midi_data/Mozart/K191 Bassoon Concerto 1mov.mid
# Copied: /tmp/midiclassics/Mozart/K626 Requiem 07 Lacrimosa.mid -> /content/midi_data/Mozart/K626 Requiem 07 Lacrimosa.mid
# Copied: /tmp/midiclassics/Mozart/K314 Flute Concerto n2 3mov.mid -> /content/midi_data/Mozart/K314 Flute Concerto n2 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Viennese Sonatinas K439b n2 1mov.mid -> /content/midi_data/Mozart/Viennese Sonatinas K439b n2 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Viennese Sonatinas K439b n2 3mov.mid -> /content/midi_data/Mozart/Viennese Sonatinas K439b n2 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Fantasia in D, K397.mid -> /content/midi_data/Mozart/Fantasia in D, K397.mid
# Copied: /tmp/midiclassics/Mozart/A piece for Piano,K.176.mid -> /content/midi_data/Mozart/A piece for Piano,K.176.mid
# Copied: /tmp/midiclassics/Mozart/K492 Overture ''Le Nozze di Figaro''.mid -> /content/midi_data/Mozart/K492 Overture ''Le Nozze di Figaro''.mid
# Copied: /tmp/midiclassics/Mozart/K495 Horn Concerto n4 1mov.mid -> /content/midi_data/Mozart/K495 Horn Concerto n4 1mov.mid
# Copied: /tmp/midiclassics/Mozart/The Chelsea Notebook/Early Pieces n18 Little Song.mid -> /content/midi_data/Mozart/Early Pieces n18 Little Song.mid
# Copied: /tmp/midiclassics/Mozart/The Chelsea Notebook/Early Pieces n5 Country Dance.mid -> /content/midi_data/Mozart/Early Pieces n5 Country Dance.mid
# Copied: /tmp/midiclassics/Mozart/The Chelsea Notebook/Early Pieces n13 Prelude.mid -> /content/midi_data/Mozart/Early Pieces n13 Prelude.mid
# Copied: /tmp/midiclassics/Mozart/The Chelsea Notebook/Early Pieces n11 Country dance.mid -> /content/midi_data/Mozart/Early Pieces n11 Country dance.mid
# Copied: /tmp/midiclassics/Mozart/The Chelsea Notebook/Early Pieces n15 Andantino.mid -> /content/midi_data/Mozart/Early Pieces n15 Andantino.mid
# Copied: /tmp/midiclassics/Mozart/The Chelsea Notebook/Early Pieces n19 Giga.mid -> /content/midi_data/Mozart/Early Pieces n19 Giga.mid
# Copied: /tmp/midiclassics/Mozart/The Chelsea Notebook/Early Pieces n8 Minuet.mid -> /content/midi_data/Mozart/Early Pieces n8 Minuet.mid
# Copied: /tmp/midiclassics/Mozart/The Chelsea Notebook/Early Pieces n10 Air.mid -> /content/midi_data/Mozart/Early Pieces n10 Air.mid
# Copied: /tmp/midiclassics/Mozart/The Chelsea Notebook/Early Pieces n16 Minuet.mid -> /content/midi_data/Mozart/Early Pieces n16 Minuet.mid
# Copied: /tmp/midiclassics/Mozart/The Chelsea Notebook/Early Pieces n12 Rondino.mid -> /content/midi_data/Mozart/Early Pieces n12 Rondino.mid
# Copied: /tmp/midiclassics/Mozart/The Chelsea Notebook/Early Pieces n6 Llittle minuet.mid -> /content/midi_data/Mozart/Early Pieces n6 Llittle minuet.mid
# Copied: /tmp/midiclassics/Mozart/The Chelsea Notebook/Early Pieces n1 Andante.mid -> /content/midi_data/Mozart/Early Pieces n1 Andante.mid
# Copied: /tmp/midiclassics/Mozart/The Chelsea Notebook/Early Pieces n7 Country dance.mid -> /content/midi_data/Mozart/Early Pieces n7 Country dance.mid
# Copied: /tmp/midiclassics/Mozart/The Chelsea Notebook/Early Pieces n3 Little march.mid -> /content/midi_data/Mozart/Early Pieces n3 Little march.mid
# Copied: /tmp/midiclassics/Mozart/The Chelsea Notebook/Early Pieces n20 Presto.mid -> /content/midi_data/Mozart/Early Pieces n20 Presto.mid
# Copied: /tmp/midiclassics/Mozart/The Chelsea Notebook/Early Pieces n14 Rondo.mid -> /content/midi_data/Mozart/Early Pieces n14 Rondo.mid
# Copied: /tmp/midiclassics/Mozart/The Chelsea Notebook/Early Pieces n17 Siciliano.mid -> /content/midi_data/Mozart/Early Pieces n17 Siciliano.mid
# Copied: /tmp/midiclassics/Mozart/The Chelsea Notebook/Early Pieces n4 Minuet.mid -> /content/midi_data/Mozart/Early Pieces n4 Minuet.mid
# Copied: /tmp/midiclassics/Mozart/The Chelsea Notebook/Early Pieces n2 Minuet.mid -> /content/midi_data/Mozart/Early Pieces n2 Minuet.mid
# Copied: /tmp/midiclassics/Mozart/The Chelsea Notebook/Early Pieces n9 Allegretto.mid -> /content/midi_data/Mozart/Early Pieces n9 Allegretto.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n18 K456 2mov ''Paradis''.mid -> /content/midi_data/Mozart/Piano Concerto n18 K456 2mov ''Paradis''.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n17 K453 3mov.mid -> /content/midi_data/Mozart/Piano Concerto n17 K453 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n7 for 3 Pianos K242 2mov ''Lodron''.mid -> /content/midi_data/Mozart/Piano Concerto n7 for 3 Pianos K242 2mov ''Lodron''.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n23 K488 2mov.mid -> /content/midi_data/Mozart/Piano Concerto n23 K488 2mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n23 K488 3mov.mid -> /content/midi_data/Mozart/Piano Concerto n23 K488 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n24 K491 2mov.mid -> /content/midi_data/Mozart/Piano Concerto n24 K491 2mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n23 K488 1mov.mid -> /content/midi_data/Mozart/Piano Concerto n23 K488 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n21 K467 2mov ''Elvira Madigan''.mid -> /content/midi_data/Mozart/Piano Concerto n21 K467 2mov ''Elvira Madigan''.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n26 K537 2mov ''Coronation''.mid -> /content/midi_data/Mozart/Piano Concerto n26 K537 2mov ''Coronation''.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n14 K449 2mov.mid -> /content/midi_data/Mozart/Piano Concerto n14 K449 2mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n20 K466 3mov.mid -> /content/midi_data/Mozart/Piano Concerto n20 K466 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n26 K537 1mov ''Coronation''.mid -> /content/midi_data/Mozart/Piano Concerto n26 K537 1mov ''Coronation''.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n25 K503 3mov.mid -> /content/midi_data/Mozart/Piano Concerto n25 K503 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n24 K491 1mov.mid -> /content/midi_data/Mozart/Piano Concerto n24 K491 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n21 K467 3mov ''Elvira Madigan''.mid -> /content/midi_data/Mozart/Piano Concerto n21 K467 3mov ''Elvira Madigan''.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n6 K238 1mov.mid -> /content/midi_data/Mozart/Piano Concerto n6 K238 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n8 K246 1mov.mid -> /content/midi_data/Mozart/Piano Concerto n8 K246 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n6 K238 3mov.mid -> /content/midi_data/Mozart/Piano Concerto n6 K238 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n8 K246 3mov.mid -> /content/midi_data/Mozart/Piano Concerto n8 K246 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n16 K451 1mov.mid -> /content/midi_data/Mozart/Piano Concerto n16 K451 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n20 K466 2mov.mid -> /content/midi_data/Mozart/Piano Concerto n20 K466 2mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n7 for 3 Pianos K242 1mov ''Lodron''.mid -> /content/midi_data/Mozart/Piano Concerto n7 for 3 Pianos K242 1mov ''Lodron''.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n12 K414 1mov.mid -> /content/midi_data/Mozart/Piano Concerto n12 K414 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n25 K503 1mov.mid -> /content/midi_data/Mozart/Piano Concerto n25 K503 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n18 K456 1mov ''Paradis''.mid -> /content/midi_data/Mozart/Piano Concerto n18 K456 1mov ''Paradis''.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n25 K503 2mov.mid -> /content/midi_data/Mozart/Piano Concerto n25 K503 2mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n24 K491 3mov.mid -> /content/midi_data/Mozart/Piano Concerto n24 K491 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n7 for 3 Pianos K242 3mov ''Lodron''.mid -> /content/midi_data/Mozart/Piano Concerto n7 for 3 Pianos K242 3mov ''Lodron''.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n21 K467 1mov ''Elvira Madigan''.mid -> /content/midi_data/Mozart/Piano Concerto n21 K467 1mov ''Elvira Madigan''.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n16 K451 3mov.mid -> /content/midi_data/Mozart/Piano Concerto n16 K451 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n18 K456 3mov ''Paradis''.mid -> /content/midi_data/Mozart/Piano Concerto n18 K456 3mov ''Paradis''.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n14 K449 3mov.mid -> /content/midi_data/Mozart/Piano Concerto n14 K449 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n20 K466 1mov.mid -> /content/midi_data/Mozart/Piano Concerto n20 K466 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n14 K449 1mov.mid -> /content/midi_data/Mozart/Piano Concerto n14 K449 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n12 K414 3mov.mid -> /content/midi_data/Mozart/Piano Concerto n12 K414 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Concertos/Piano Concerto n26 K537 3mov ''Coronation''.mid -> /content/midi_data/Mozart/Piano Concerto n26 K537 3mov ''Coronation''.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Piano Sonata n16 K545.mid -> /content/midi_data/Mozart/Piano Sonata n16 K545.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Piano Sonata n19 K576.mid -> /content/midi_data/Mozart/Piano Sonata n19 K576.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Piano Sonata n04 K282.mid -> /content/midi_data/Mozart/Piano Sonata n04 K282.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Piano Sonata n14 K457.mid -> /content/midi_data/Mozart/Piano Sonata n14 K457.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Piano Sonata n02 K280.mid -> /content/midi_data/Mozart/Piano Sonata n02 K280.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Piano Sonata n12 K332.mid -> /content/midi_data/Mozart/Piano Sonata n12 K332.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Piano Sonata n03 K281.mid -> /content/midi_data/Mozart/Piano Sonata n03 K281.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Piano Sonata n18 K570.mid -> /content/midi_data/Mozart/Piano Sonata n18 K570.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Piano Sonata n05 K283.mid -> /content/midi_data/Mozart/Piano Sonata n05 K283.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Piano Sonata n11 K331.mid -> /content/midi_data/Mozart/Piano Sonata n11 K331.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Piano Sonata n08 K311.mid -> /content/midi_data/Mozart/Piano Sonata n08 K311.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Piano Sonata n15 K593-494.mid -> /content/midi_data/Mozart/Piano Sonata n15 K593-494.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Piano Sonata n01 K279.mid -> /content/midi_data/Mozart/Piano Sonata n01 K279.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Piano Sonata n10 K330.mid -> /content/midi_data/Mozart/Piano Sonata n10 K330.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Piano Sonata n17 K547a.mid -> /content/midi_data/Mozart/Piano Sonata n17 K547a.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Piano Sonata n07 K309.mid -> /content/midi_data/Mozart/Piano Sonata n07 K309.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Piano Sonata n13 K333.mid -> /content/midi_data/Mozart/Piano Sonata n13 K333.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Piano Sonata n06 K284.mid -> /content/midi_data/Mozart/Piano Sonata n06 K284.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Piano Sonata n09 K310.mid -> /content/midi_data/Mozart/Piano Sonata n09 K310.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K457 Piano Sonata n14 .mid -> /content/midi_data/Mozart/K457 Piano Sonata n14 .mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K279 Piano sonata n01 1mov.mid -> /content/midi_data/Mozart/K279 Piano sonata n01 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K333 Piano Sonata n13 3mov.mid -> /content/midi_data/Mozart/K333 Piano Sonata n13 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K19d Piano Sonata Duet.mid -> /content/midi_data/Mozart/K19d Piano Sonata Duet.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K280 Piano sonata n02 1mov.mid -> /content/midi_data/Mozart/K280 Piano sonata n02 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K331 Piano Sonata n11 .mid -> /content/midi_data/Mozart/K331 Piano Sonata n11 .mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K281 Piano Sonata n03 2mov.mid -> /content/midi_data/Mozart/K281 Piano Sonata n03 2mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K333 Piano Sonata n13 .mid -> /content/midi_data/Mozart/K333 Piano Sonata n13 .mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K309 Piano Sonata n10 1mov.mid -> /content/midi_data/Mozart/K309 Piano Sonata n10 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K309 Piano Sonata n10 2mov.mid -> /content/midi_data/Mozart/K309 Piano Sonata n10 2mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K333 Piano Sonata n13 2mov.mid -> /content/midi_data/Mozart/K333 Piano Sonata n13 2mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K281 Piano Sonata n03 3mov.mid -> /content/midi_data/Mozart/K281 Piano Sonata n03 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K358 Piano Sonata 4 Hands.mid -> /content/midi_data/Mozart/K358 Piano Sonata 4 Hands.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K330 Piano Sonata n10 2mov.mid -> /content/midi_data/Mozart/K330 Piano Sonata n10 2mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K279 Piano sonata n01 3mov.mid -> /content/midi_data/Mozart/K279 Piano sonata n01 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K281 Piano Sonata n03 1mov.mid -> /content/midi_data/Mozart/K281 Piano Sonata n03 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K280 Piano sonata n02 2mov.mid -> /content/midi_data/Mozart/K280 Piano sonata n02 2mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K333 Piano Sonata n13 1mov.mid -> /content/midi_data/Mozart/K333 Piano Sonata n13 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K331 Piano sonata n11 3mov.mid -> /content/midi_data/Mozart/K331 Piano sonata n11 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K332 Piano Sonata n12 1mov.mid -> /content/midi_data/Mozart/K332 Piano Sonata n12 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K332 Piano Sonata n12 3mov.mid -> /content/midi_data/Mozart/K332 Piano Sonata n12 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K279 Piano sonata n01 2mov.mid -> /content/midi_data/Mozart/K279 Piano sonata n01 2mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K521 Piano Sonata 4 Hands.mid -> /content/midi_data/Mozart/K521 Piano Sonata 4 Hands.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K497 Piano Sonata 4 Hands.mid -> /content/midi_data/Mozart/K497 Piano Sonata 4 Hands.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K570 Piano Sonata 3mov.mid -> /content/midi_data/Mozart/K570 Piano Sonata 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K545 Piano Sonata.mid -> /content/midi_data/Mozart/K545 Piano Sonata.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K332 Piano Sonata n12 2mov.mid -> /content/midi_data/Mozart/K332 Piano Sonata n12 2mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K282 Piano Sonata n04 .mid -> /content/midi_data/Mozart/K282 Piano Sonata n04 .mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K381 Piano Sonata 4 Hands.mid -> /content/midi_data/Mozart/K381 Piano Sonata 4 Hands.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K576 Piano Sonata n19 .mid -> /content/midi_data/Mozart/K576 Piano Sonata n19 .mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K309 Piano Sonata n10 3mov.mid -> /content/midi_data/Mozart/K309 Piano Sonata n10 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K280 Piano sonata n02 3mov.mid -> /content/midi_data/Mozart/K280 Piano sonata n02 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K570 Piano Sonata 2mov.mid -> /content/midi_data/Mozart/K570 Piano Sonata 2mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K330 Piano Sonata n10 3mov.mid -> /content/midi_data/Mozart/K330 Piano Sonata n10 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K357 Piano Sonata 4 Hands.mid -> /content/midi_data/Mozart/K357 Piano Sonata 4 Hands.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K330 Piano Sonata n10 1mov.mid -> /content/midi_data/Mozart/K330 Piano Sonata n10 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K570 Piano Sonata 1mov.mid -> /content/midi_data/Mozart/K570 Piano Sonata 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Piano Sonatas/Nueva carpeta/K284 Piano Sonata n06 .mid -> /content/midi_data/Mozart/K284 Piano Sonata n06 .mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n34 K338 1mov.mid -> /content/midi_data/Mozart/Symphony n34 K338 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n38 K504 3mov ''Prague''.mid -> /content/midi_data/Mozart/Symphony n38 K504 3mov ''Prague''.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n30 K202 4mov.mid -> /content/midi_data/Mozart/Symphony n30 K202 4mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n35 K385 3mov ''Haffner''.mid -> /content/midi_data/Mozart/Symphony n35 K385 3mov ''Haffner''.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n28 K200 1mov.mid -> /content/midi_data/Mozart/Symphony n28 K200 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n25 K183 4mov.mid -> /content/midi_data/Mozart/Symphony n25 K183 4mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n5 K022.mid -> /content/midi_data/Mozart/Symphony n5 K022.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n39 K543 3mov.mid -> /content/midi_data/Mozart/Symphony n39 K543 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n39 K543 4mov.mid -> /content/midi_data/Mozart/Symphony n39 K543 4mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n33 K319 3mov.mid -> /content/midi_data/Mozart/Symphony n33 K319 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n30 K202 3mov.mid -> /content/midi_data/Mozart/Symphony n30 K202 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n29 K201 4mov.mid -> /content/midi_data/Mozart/Symphony n29 K201 4mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n37 K444 1mov.mid -> /content/midi_data/Mozart/Symphony n37 K444 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n40 K550 3mov.mid -> /content/midi_data/Mozart/Symphony n40 K550 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n40 K550 1mov.mid -> /content/midi_data/Mozart/Symphony n40 K550 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n33 K319 4mov.mid -> /content/midi_data/Mozart/Symphony n33 K319 4mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n34 K338 2mov.mid -> /content/midi_data/Mozart/Symphony n34 K338 2mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n28 K200 3mov.mid -> /content/midi_data/Mozart/Symphony n28 K200 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n31 K297 1mov ''Paris''.mid -> /content/midi_data/Mozart/Symphony n31 K297 1mov ''Paris''.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n4 K19 3mov.mid -> /content/midi_data/Mozart/Symphony n4 K19 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n28 K200 2mov.mid -> /content/midi_data/Mozart/Symphony n28 K200 2mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n41 K551 3mov ''Jupiter''.mid -> /content/midi_data/Mozart/Symphony n41 K551 3mov ''Jupiter''.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n34 K338 3mov.mid -> /content/midi_data/Mozart/Symphony n34 K338 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n36 K425 4mov ''Linz''.mid -> /content/midi_data/Mozart/Symphony n36 K425 4mov ''Linz''.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n35 K385 1mov ''Haffner''.mid -> /content/midi_data/Mozart/Symphony n35 K385 1mov ''Haffner''.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n41 K551 2mov ''Jupiter''.mid -> /content/midi_data/Mozart/Symphony n41 K551 2mov ''Jupiter''.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n40 K550 4mov.mid -> /content/midi_data/Mozart/Symphony n40 K550 4mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n33 K319 2mov.mid -> /content/midi_data/Mozart/Symphony n33 K319 2mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n36 K425 2mov ''Linz''.mid -> /content/midi_data/Mozart/Symphony n36 K425 2mov ''Linz''.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n39 K543 2mov.mid -> /content/midi_data/Mozart/Symphony n39 K543 2mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n36 K425 3mov ''Linz''.mid -> /content/midi_data/Mozart/Symphony n36 K425 3mov ''Linz''.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n29 K201 1mov.mid -> /content/midi_data/Mozart/Symphony n29 K201 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n22 K162 1mov.mid -> /content/midi_data/Mozart/Symphony n22 K162 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n38 K504 2mov ''Prague''.mid -> /content/midi_data/Mozart/Symphony n38 K504 2mov ''Prague''.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n35 K385 4mov ''Haffner''.mid -> /content/midi_data/Mozart/Symphony n35 K385 4mov ''Haffner''.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n41 K551 4mov ''Jupiter''.mid -> /content/midi_data/Mozart/Symphony n41 K551 4mov ''Jupiter''.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n31 K297 3mov ''Paris''.mid -> /content/midi_data/Mozart/Symphony n31 K297 3mov ''Paris''.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n33 K319 1mov.mid -> /content/midi_data/Mozart/Symphony n33 K319 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n25 K183 2mov.mid -> /content/midi_data/Mozart/Symphony n25 K183 2mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n4 K019 1mov.mid -> /content/midi_data/Mozart/Symphony n4 K019 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n30 K202 2mov.mid -> /content/midi_data/Mozart/Symphony n30 K202 2mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n31 K297 2mov ''Paris''.mid -> /content/midi_data/Mozart/Symphony n31 K297 2mov ''Paris''.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n25 K183 1mov.mid -> /content/midi_data/Mozart/Symphony n25 K183 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n40 K550 2mov.mid -> /content/midi_data/Mozart/Symphony n40 K550 2mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n38 K504 1mov ''Prague''.mid -> /content/midi_data/Mozart/Symphony n38 K504 1mov ''Prague''.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n35 K385 2mov ''Haffner''.mid -> /content/midi_data/Mozart/Symphony n35 K385 2mov ''Haffner''.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n30 K202 1mov.mid -> /content/midi_data/Mozart/Symphony n30 K202 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n36 K425 1mov ''Linz''.mid -> /content/midi_data/Mozart/Symphony n36 K425 1mov ''Linz''.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n25 K183 3mov.mid -> /content/midi_data/Mozart/Symphony n25 K183 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n41 K551 1mov ''Jupiter''.mid -> /content/midi_data/Mozart/Symphony n41 K551 1mov ''Jupiter''.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n22 K162 3mov.mid -> /content/midi_data/Mozart/Symphony n22 K162 3mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n28 K200 4mov.mid -> /content/midi_data/Mozart/Symphony n28 K200 4mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n39 K543 1mov.mid -> /content/midi_data/Mozart/Symphony n39 K543 1mov.mid
# Copied: /tmp/midiclassics/Mozart/Symphonies/Symphony n29 K201 2mov.mid -> /content/midi_data/Mozart/Symphony n29 K201 2mov.mid
# Copied: /tmp/midiclassics/Chopin/Trois Nouvelles Etudes (Op.posth.).mid -> /content/midi_data/Chopin/Trois Nouvelles Etudes (Op.posth.).mid
# Copied: /tmp/midiclassics/Chopin/Sonata No.3 1st Mov Allegro.mid -> /content/midi_data/Chopin/Sonata No.3 1st Mov Allegro.mid
# Copied: /tmp/midiclassics/Chopin/Prelude n05 op28 ''Uncertainty''.mid -> /content/midi_data/Chopin/Prelude n05 op28 ''Uncertainty''.mid
# Copied: /tmp/midiclassics/Chopin/Mazurka op7 n2.mid -> /content/midi_data/Chopin/Mazurka op7 n2.mid
# Copied: /tmp/midiclassics/Chopin/Ballad op53.mid -> /content/midi_data/Chopin/Ballad op53.mid
# Copied: /tmp/midiclassics/Chopin/Etude op25 n05.mid -> /content/midi_data/Chopin/Etude op25 n05.mid
# Copied: /tmp/midiclassics/Chopin/Ecossaise No.2 in G.mid -> /content/midi_data/Chopin/Ecossaise No.2 in G.mid
# Copied: /tmp/midiclassics/Chopin/Etude op10 n04 Drchew.mid -> /content/midi_data/Chopin/Etude op10 n04 Drchew.mid
# Copied: /tmp/midiclassics/Chopin/Prelude n14 op28 ''Fear''.mid -> /content/midi_data/Chopin/Prelude n14 op28 ''Fear''.mid
# Copied: /tmp/midiclassics/Chopin/Piano Concerto n2 3mov.mid -> /content/midi_data/Chopin/Piano Concerto n2 3mov.mid
# Copied: /tmp/midiclassics/Chopin/Etude No.7 in C Major Opus.10, No.7.mid -> /content/midi_data/Chopin/Etude No.7 in C Major Opus.10, No.7.mid
# Copied: /tmp/midiclassics/Chopin/Prelude n11 op28 ''Dragonfly''.mid -> /content/midi_data/Chopin/Prelude n11 op28 ''Dragonfly''.mid
# Copied: /tmp/midiclassics/Chopin/Prelude n16 op28 ''Hades''.mid -> /content/midi_data/Chopin/Prelude n16 op28 ''Hades''.mid
# Copied: /tmp/midiclassics/Chopin/Piano Concerto n2 1mov.mid -> /content/midi_data/Chopin/Piano Concerto n2 1mov.mid
# Copied: /tmp/midiclassics/Chopin/Polonaise Opus.40, No.1 (Military).mid -> /content/midi_data/Chopin/Polonaise Opus.40, No.1 (Military).mid
# Copied: /tmp/midiclassics/Chopin/Piano Concerto n1 op11 3mov.mid -> /content/midi_data/Chopin/Piano Concerto n1 op11 3mov.mid
# Copied: /tmp/midiclassics/Chopin/Etude op10 n12 ''Revolutionary''.mid -> /content/midi_data/Chopin/Etude op10 n12 ''Revolutionary''.mid
# Copied: /tmp/midiclassics/Chopin/Nocturne op72 n1.mid -> /content/midi_data/Chopin/Nocturne op72 n1.mid
# Copied: /tmp/midiclassics/Chopin/Etude op10 n06.mid -> /content/midi_data/Chopin/Etude op10 n06.mid
# Copied: /tmp/midiclassics/Chopin/Prelude n13 op28 ''Loss''.mid -> /content/midi_data/Chopin/Prelude n13 op28 ''Loss''.mid
# Copied: /tmp/midiclassics/Chopin/Nocturne op37 01.mid -> /content/midi_data/Chopin/Nocturne op37 01.mid
# Copied: /tmp/midiclassics/Chopin/2 Polonaises op26 n1.mid -> /content/midi_data/Chopin/2 Polonaises op26 n1.mid
# Copied: /tmp/midiclassics/Chopin/Nocturne op27 n1.mid -> /content/midi_data/Chopin/Nocturne op27 n1.mid
# Copied: /tmp/midiclassics/Chopin/19 Polish Songs, for Solo Voice and Piano accomplements, No.8.mid -> /content/midi_data/Chopin/19 Polish Songs, for Solo Voice and Piano accomplements, No.8.mid
# Copied: /tmp/midiclassics/Chopin/Etude op25 n01 ''Harp Etude''.mid -> /content/midi_data/Chopin/Etude op25 n01 ''Harp Etude''.mid
# Copied: /tmp/midiclassics/Chopin/Etude op25 n11 ''Winter Wind''.mid -> /content/midi_data/Chopin/Etude op25 n11 ''Winter Wind''.mid
# Copied: /tmp/midiclassics/Chopin/19 Polish Songs, for Solo Voice and Piano accomplements, No.16.mid -> /content/midi_data/Chopin/19 Polish Songs, for Solo Voice and Piano accomplements, No.16.mid
# Copied: /tmp/midiclassics/Chopin/Prelude op.28-15 Raindrop.mid -> /content/midi_data/Chopin/Prelude op.28-15 Raindrop.mid
# Copied: /tmp/midiclassics/Chopin/19 Polish Songs, for Solo Voice and Piano accomplements, No.11.mid -> /content/midi_data/Chopin/19 Polish Songs, for Solo Voice and Piano accomplements, No.11.mid
# Copied: /tmp/midiclassics/Chopin/Etude op25 n09.mid -> /content/midi_data/Chopin/Etude op25 n09.mid
# Copied: /tmp/midiclassics/Chopin/Sonata op35 n3 .mid -> /content/midi_data/Chopin/Sonata op35 n3 .mid
# Copied: /tmp/midiclassics/Chopin/Nocturne op09 n3.mid -> /content/midi_data/Chopin/Nocturne op09 n3.mid
# Copied: /tmp/midiclassics/Chopin/(2542)Prelude opus.28, No.16 in B flat minor.mid -> /content/midi_data/Chopin/(2542)Prelude opus.28, No.16 in B flat minor.mid
# Copied: /tmp/midiclassics/Chopin/Etude op25 n10.mid -> /content/midi_data/Chopin/Etude op25 n10.mid
# Copied: /tmp/midiclassics/Chopin/Etude Op.10 No.11.mid -> /content/midi_data/Chopin/Etude Op.10 No.11.mid
# Copied: /tmp/midiclassics/Chopin/Scherzo op31.mid -> /content/midi_data/Chopin/Scherzo op31.mid
# Copied: /tmp/midiclassics/Chopin/Nocturne op09 n2.mid -> /content/midi_data/Chopin/Nocturne op09 n2.mid
# Copied: /tmp/midiclassics/Chopin/Mazurka op30 n2 Drchew.mid -> /content/midi_data/Chopin/Mazurka op30 n2 Drchew.mid
# Copied: /tmp/midiclassics/Chopin/Scherzo No.2, Opus.31.mid -> /content/midi_data/Chopin/Scherzo No.2, Opus.31.mid
# ...
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Bwv1069 Orchestral Suite n4 3mov.mid -> /content/midi_data/Bach/Bwv1069 Orchestral Suite n4 3mov.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Bwv1067 Orchestral Suite n2 5mov.mid -> /content/midi_data/Bach/Bwv1067 Orchestral Suite n2 5mov.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Bwv1067 Orchestral Suite n2 1mov.mid -> /content/midi_data/Bach/Bwv1067 Orchestral Suite n2 1mov.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Bwv1067 Orchestral Suite n2 7mov.mid -> /content/midi_data/Bach/Bwv1067 Orchestral Suite n2 7mov.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Bwv1068 Orchestral Suite n3 1mov.mid -> /content/midi_data/Bach/Bwv1068 Orchestral Suite n3 1mov.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Nueva carpeta/Bwv1068 Orchestral suite n3 Gigue.mid -> /content/midi_data/Bach/Bwv1068 Orchestral suite n3 Gigue.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Nueva carpeta/Bwv1066 Orchestral suite n1 Overture.mid -> /content/midi_data/Bach/Bwv1066 Orchestral suite n1 Overture.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Nueva carpeta/Bwv1069 Orchestral suite n4 Gavotte.mid -> /content/midi_data/Bach/Bwv1069 Orchestral suite n4 Gavotte.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Nueva carpeta/Bwv1068 Orchestral suite n3 Air.mid -> /content/midi_data/Bach/Bwv1068 Orchestral suite n3 Air.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Nueva carpeta/Bwv1067 Orchestral suite n2 Rondeau.mid -> /content/midi_data/Bach/Bwv1067 Orchestral suite n2 Rondeau.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Nueva carpeta/Bwv1066 Orchestral suite n1 Gavotte.mid -> /content/midi_data/Bach/Bwv1066 Orchestral suite n1 Gavotte.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Nueva carpeta/Bwv1069 Orchestral suite n4 Overture.mid -> /content/midi_data/Bach/Bwv1069 Orchestral suite n4 Overture.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Nueva carpeta/Bwv1066 Orchestral suite n1 Courante.mid -> /content/midi_data/Bach/Bwv1066 Orchestral suite n1 Courante.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Nueva carpeta/Bwv1066 Orchestral suite n1 Passpied.mid -> /content/midi_data/Bach/Bwv1066 Orchestral suite n1 Passpied.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Nueva carpeta/Bwv1067 Orchestral suite n2 Polonais.mid -> /content/midi_data/Bach/Bwv1067 Orchestral suite n2 Polonais.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Nueva carpeta/Bwv1067 Orchestral suite n2 Overture.mid -> /content/midi_data/Bach/Bwv1067 Orchestral suite n2 Overture.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Nueva carpeta/Bwv1066 Orchestral suite n1 Forlane.mid -> /content/midi_data/Bach/Bwv1066 Orchestral suite n1 Forlane.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Nueva carpeta/Bwv1067 Orchestral suite n2 Bouree.mid -> /content/midi_data/Bach/Bwv1067 Orchestral suite n2 Bouree.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Nueva carpeta/Bwv1067 Orchestral suite n2 Menuet.mid -> /content/midi_data/Bach/Bwv1067 Orchestral suite n2 Menuet.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Nueva carpeta/Bwv1069 Orchestral suite n4 Rejouissance.mid -> /content/midi_data/Bach/Bwv1069 Orchestral suite n4 Rejouissance.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Nueva carpeta/Bwv1068 Orchestral suite n3 Bourree.mid -> /content/midi_data/Bach/Bwv1068 Orchestral suite n3 Bourree.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Nueva carpeta/Bwv1069 Orchestral suite n4 Bourree.mid -> /content/midi_data/Bach/Bwv1069 Orchestral suite n4 Bourree.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Nueva carpeta/Bwv1069 Orchestral suite n4 Menuet.mid -> /content/midi_data/Bach/Bwv1069 Orchestral suite n4 Menuet.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Nueva carpeta/Bwv1068 Orchestral suite n3 Overture.mid -> /content/midi_data/Bach/Bwv1068 Orchestral suite n3 Overture.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Nueva carpeta/Bwv1067 Orchestral suite n2 Sarabande.mid -> /content/midi_data/Bach/Bwv1067 Orchestral suite n2 Sarabande.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Nueva carpeta/Bwv1067 Orchestral suite n2 Badineri.mid -> /content/midi_data/Bach/Bwv1067 Orchestral suite n2 Badineri.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Nueva carpeta/Bwv1066 Orchestral suite n1 Menuet.mid -> /content/midi_data/Bach/Bwv1066 Orchestral suite n1 Menuet.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Nueva carpeta/Bwv1066 Orchestral suite n1 Bouree.mid -> /content/midi_data/Bach/Bwv1066 Orchestral suite n1 Bouree.mid
# Copied: /tmp/midiclassics/Bach/Bwv1066-1069 Orchestral Suites/Nueva carpeta/Bwv1068 Orchestral suite n3 Gavotte.mid -> /content/midi_data/Bach/Bwv1068 Orchestral suite n3 Gavotte.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/WTCII14A.MID -> /content/midi_data/Bach/WTCII14A.MID
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii07b.mid -> /content/midi_data/Bach/Wtcii07b.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/WTCII08A.MID -> /content/midi_data/Bach/WTCII08A.MID
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/WTCII18A.MID -> /content/midi_data/Bach/WTCII18A.MID
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii01b.mid -> /content/midi_data/Bach/Wtcii01b.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii19b.mid -> /content/midi_data/Bach/Wtcii19b.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/WTCII19A.MID -> /content/midi_data/Bach/WTCII19A.MID
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii13b.mid -> /content/midi_data/Bach/Wtcii13b.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/WTCII09A.MID -> /content/midi_data/Bach/WTCII09A.MID
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii06b.mid -> /content/midi_data/Bach/Wtcii06b.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii02b.mid -> /content/midi_data/Bach/Wtcii02b.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii10b.mid -> /content/midi_data/Bach/Wtcii10b.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/WTCII21A.MID -> /content/midi_data/Bach/WTCII21A.MID
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii24a.mid -> /content/midi_data/Bach/Wtcii24a.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/WTCII04A.MID -> /content/midi_data/Bach/WTCII04A.MID
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/WTCII23A.MID -> /content/midi_data/Bach/WTCII23A.MID
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii22b.mid -> /content/midi_data/Bach/Wtcii22b.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii24b.mid -> /content/midi_data/Bach/Wtcii24b.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii09b.mid -> /content/midi_data/Bach/Wtcii09b.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii16b.mid -> /content/midi_data/Bach/Wtcii16b.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii03b.mid -> /content/midi_data/Bach/Wtcii03b.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/WTCII15A.MID -> /content/midi_data/Bach/WTCII15A.MID
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/WTCII22A.MID -> /content/midi_data/Bach/WTCII22A.MID
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii20b.mid -> /content/midi_data/Bach/Wtcii20b.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/WTCII02A.MID -> /content/midi_data/Bach/WTCII02A.MID
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii14b.mid -> /content/midi_data/Bach/Wtcii14b.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii21b.mid -> /content/midi_data/Bach/Wtcii21b.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii23b.mid -> /content/midi_data/Bach/Wtcii23b.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii11b.mid -> /content/midi_data/Bach/Wtcii11b.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii15b.mid -> /content/midi_data/Bach/Wtcii15b.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/WTCII20A.MID -> /content/midi_data/Bach/WTCII20A.MID
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/WTCII07A.MID -> /content/midi_data/Bach/WTCII07A.MID
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/WTCII06A.MID -> /content/midi_data/Bach/WTCII06A.MID
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii17b.mid -> /content/midi_data/Bach/Wtcii17b.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/WTCII16A.MID -> /content/midi_data/Bach/WTCII16A.MID
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/WTCII12A.MID -> /content/midi_data/Bach/WTCII12A.MID
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii10a.mid -> /content/midi_data/Bach/Wtcii10a.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii11a.mid -> /content/midi_data/Bach/Wtcii11a.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/WTCII13A.MID -> /content/midi_data/Bach/WTCII13A.MID
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii18b.mid -> /content/midi_data/Bach/Wtcii18b.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii08b.mid -> /content/midi_data/Bach/Wtcii08b.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/WTCII17A.MID -> /content/midi_data/Bach/WTCII17A.MID
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii12b.mid -> /content/midi_data/Bach/Wtcii12b.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii04b.mid -> /content/midi_data/Bach/Wtcii04b.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii01a.mid -> /content/midi_data/Bach/Wtcii01a.mid
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/WTCII05A.MID -> /content/midi_data/Bach/WTCII05A.MID
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/WTCII03A.MID -> /content/midi_data/Bach/WTCII03A.MID
# Copied: /tmp/midiclassics/Bach/Bwv870-893 The Well Tempered Clavier Book 2/Wtcii05b.mid -> /content/midi_data/Bach/Wtcii05b.mid
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1046 Brandenburg Concert n1 3mov.mid -> /content/midi_data/Bach/Bwv1046 Brandenburg Concert n1 3mov.mid
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1041 Violin Concerto n1 1mov.mid -> /content/midi_data/Bach/Bwv1041 Violin Concerto n1 1mov.mid
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1051 Brandenburg Concert n6 2mov.mid -> /content/midi_data/Bach/Bwv1051 Brandenburg Concert n6 2mov.mid
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1048 Brandenburg Concert n3 2-3movs.MID -> /content/midi_data/Bach/Bwv1048 Brandenburg Concert n3 2-3movs.MID
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1047 Brandenburg Concert n2 3mov.mid -> /content/midi_data/Bach/Bwv1047 Brandenburg Concert n2 3mov.mid
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1046 Brandenburg Concert n1 1mov.mid -> /content/midi_data/Bach/Bwv1046 Brandenburg Concert n1 1mov.mid
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1046 Brandenburg Concert n1 2mov.mid -> /content/midi_data/Bach/Bwv1046 Brandenburg Concert n1 2mov.mid
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1049 Brandenburg Concert n4 2mov.mid -> /content/midi_data/Bach/Bwv1049 Brandenburg Concert n4 2mov.mid
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1042 Violin Concerto n2 3mov.mid -> /content/midi_data/Bach/Bwv1042 Violin Concerto n2 3mov.mid
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1043 Two Violins Concerto n3 2mov.mid -> /content/midi_data/Bach/Bwv1043 Two Violins Concerto n3 2mov.mid
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1047 Brandenburg Concert n2 2mov.mid -> /content/midi_data/Bach/Bwv1047 Brandenburg Concert n2 2mov.mid
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1044 Flute Violin and Harpsichord Concerto 2mov.mid -> /content/midi_data/Bach/Bwv1044 Flute Violin and Harpsichord Concerto 2mov.mid
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1047 Brandenburg Concert n2 1mov.mid -> /content/midi_data/Bach/Bwv1047 Brandenburg Concert n2 1mov.mid
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1049 Brandenburg Concert n4 1mov.mid -> /content/midi_data/Bach/Bwv1049 Brandenburg Concert n4 1mov.mid
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1048 Brandenburg Concert n3 1mov.mid -> /content/midi_data/Bach/Bwv1048 Brandenburg Concert n3 1mov.mid
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1051 Brandenburg Concert n6 1mov.mid -> /content/midi_data/Bach/Bwv1051 Brandenburg Concert n6 1mov.mid
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1051 Brandenburg Concert n6 3mov.mid -> /content/midi_data/Bach/Bwv1051 Brandenburg Concert n6 3mov.mid
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1041 Violin Concerto n1 3mov.mid -> /content/midi_data/Bach/Bwv1041 Violin Concerto n1 3mov.mid
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1043 Two Violins Concerto n3 3mov.mid -> /content/midi_data/Bach/Bwv1043 Two Violins Concerto n3 3mov.mid
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1042 Violin Concerto n2 1mov.mid -> /content/midi_data/Bach/Bwv1042 Violin Concerto n2 1mov.mid
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1048 Brandenburg Concert n3 1mov B.MID -> /content/midi_data/Bach/Bwv1048 Brandenburg Concert n3 1mov B.MID
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1050 Brandenburg Concert n5 1-2-3movs.MID -> /content/midi_data/Bach/Bwv1050 Brandenburg Concert n5 1-2-3movs.MID
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1042 Violin Concerto n2 2mov.mid -> /content/midi_data/Bach/Bwv1042 Violin Concerto n2 2mov.mid
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1049 Brandenburg Concert n4 3mov.mid -> /content/midi_data/Bach/Bwv1049 Brandenburg Concert n4 3mov.mid
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1044 Flute Violin and Harpsichord Concerto 3mov.mid -> /content/midi_data/Bach/Bwv1044 Flute Violin and Harpsichord Concerto 3mov.mid
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1043 Two Violins Concerto n3 1mov.mid -> /content/midi_data/Bach/Bwv1043 Two Violins Concerto n3 1mov.mid
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1041 Violin Concerto n1 2mov.mid -> /content/midi_data/Bach/Bwv1041 Violin Concerto n1 2mov.mid
# Copied: /tmp/midiclassics/Bach/Concertos/Bwv1044 Flute Violin and Harpsichord Concerto 1mov.mid -> /content/midi_data/Bach/Bwv1044 Flute Violin and Harpsichord Concerto 1mov.mid
# Copied: /tmp/midiclassics/Rimsky-Korsakov/Six variations on Bach No.1.mid -> /content/midi_data/Bach/Six variations on Bach No.1.mid
# Copied: /tmp/midiclassics/Rimsky-Korsakov/Six variations on Bach No.3.mid -> /content/midi_data/Bach/Six variations on Bach No.3.mid
#
#  MIDI File Summary per Composer:
# ----------------------------------
# Bach: 1050 files
# Beethoven: 220 files
# Chopin: 138 files
# Mozart: 259 files

# %%
# ----------------------------------
# Create DataFrame of all MIDI file paths per composer
# ----------------------------------
def create_midi_file_dataframe(base_dir, composers):
    import os
    import pandas as pd

    matched_paths = []

    for composer in composers:
        composer_dir = os.path.join(base_dir, composer)
        if not os.path.exists(composer_dir):
            print(f"[WARNING] Missing folder: {composer_dir}")
            continue

        for root, _, files in os.walk(composer_dir):
            for f in files:
                if f.lower().endswith(('.mid', '.midi')):
                    file_path = os.path.join(root, f)
                    matched_paths.append(file_path)

    # Create and return DataFrame
    df = pd.DataFrame(matched_paths, columns=['filepath'])
    pd.set_option('display.max_colwidth', None)
    return df

df = create_midi_file_dataframe(MIDI_DATA_DIR, COMPOSERS)
print(df)
# Out:
#                                                                           filepath
# 0                                             /content/midi_data/Bach/008906b_.mid
# 1                                             /content/midi_data/Bach/WTCII14A.MID
# 2                                             /content/midi_data/Bach/024437b_.mid
# 3     /content/midi_data/Bach/Piano version of Bachs two part inventions No.13.mid
# 4                                         /content/midi_data/Bach/Variation 26.mid
# ...                                                                            ...
# 1662                          /content/midi_data/Mozart/K570 Piano Sonata 1mov.mid
# 1663                          /content/midi_data/Mozart/Symphony n39 K543 1mov.mid
# 1664                          /content/midi_data/Mozart/Symphony n29 K201 2mov.mid
# 1665                           /content/midi_data/Mozart/Piano Sonata n09 K310.mid
# 1666                          /content/midi_data/Mozart/K284 Piano Sonata n06 .mid
#
# [1667 rows x 1 columns]
